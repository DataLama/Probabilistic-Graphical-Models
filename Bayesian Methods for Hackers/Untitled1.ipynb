# %%
import pandas as pd
import numpy as np
data = pd.read_csv('toner_20.01-20.04 sales.tsv',sep='\t')

# %%
df = data.loc[2:].reset_index(drop=True)
df = df.astype({'정상판매금액':np.float64, '상품판매금액':np.float64, '최종결제금액':np.float64})
df['일자'] = pd.to_datetime(df['일자'])

# %%
import pandas_profiling
pr=data.profile_report() 

# pr.to_file('./pr_report.html')

# %%
pr.to_file('pr_report.html')
# Out:
# ...
# /usr/local/lib/python3.6/dist-packages/matplotlib/textpath.py:84: RuntimeWarning: Glyph 54032 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /usr/local/lib/python3.6/dist-packages/matplotlib/textpath.py:84: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /usr/local/lib/python3.6/dist-packages/matplotlib/textpath.py:84: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /usr/local/lib/python3.6/dist-packages/matplotlib/textpath.py:84: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
# ...
